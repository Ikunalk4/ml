# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikunalk4/ml/blob/main/Car_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
from sklearn import linear_model
import seaborn as sns

# %%
car_df = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv')

# %%
car_df.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_df.describe()
# Out:
#            car_ID   symboling   wheelbase  ...     citympg  highwaympg         price
# count  205.000000  205.000000  205.000000  ...  205.000000  205.000000    205.000000
# mean   103.000000    0.834146   98.756585  ...   25.219512   30.751220  13276.710571
# std     59.322565    1.245307    6.021776  ...    6.542142    6.886443   7988.852332
# min      1.000000   -2.000000   86.600000  ...   13.000000   16.000000   5118.000000
# 25%     52.000000    0.000000   94.500000  ...   19.000000   25.000000   7788.000000
# 50%    103.000000    1.000000   97.000000  ...   24.000000   30.000000  10295.000000
# 75%    154.000000    2.000000  102.400000  ...   30.000000   34.000000  16503.000000
# max    205.000000    3.000000  120.900000  ...   49.000000   54.000000  45400.000000
#
# [8 rows x 16 columns]

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car_df.shape
# Out:
# (205, 26)

# %%
car_df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car_df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
car_df.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
car_df.carbody.unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
fig = px.histogram(car_df,x='cylindernumber',color='fueltype',nbins=7,title='Distribution of with the number of cylinder')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="85853b6f-26ec-4307-910f-50465b7ecc32" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85853b6f-26ec-4307-910f-50465b7ecc32")) {
#                     Plotly.newPlot(
#                         '85853b6f-26ec-4307-910f-50465b7ecc32',
# ...

# %%
plt.figure(figsize=(15, 10))
sns.distplot(car_df.price)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
plt.figure(figsize=(15, 10))
sns.barplot(car_df['enginesize'], car_df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x = 'horsepower', y = 'price', data = car_df,color="Red")

# %%
fig = px.scatter(car_df, 
                 x='price', 
                 y='enginesize', 
                 opacity=0.8, 
                 title='price vs enginesize')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cd78935f-7f52-42cf-91c7-b72137632b22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd78935f-7f52-42cf-91c7-b72137632b22")) {
#                     Plotly.newPlot(
#                         'cd78935f-7f52-42cf-91c7-b72137632b22',
# ...

# %%
car_df.corr()
# Out:
#                     car_ID  symboling  ...  highwaympg     price
# car_ID            1.000000  -0.151621  ...    0.011255 -0.109093
# symboling        -0.151621   1.000000  ...    0.034606 -0.079978
# wheelbase         0.129729  -0.531954  ...   -0.544082  0.577816
# carlength         0.170636  -0.357612  ...   -0.704662  0.682920
# carwidth          0.052387  -0.232919  ...   -0.677218  0.759325
# carheight         0.255960  -0.541038  ...   -0.107358  0.119336
# curbweight        0.071962  -0.227691  ...   -0.797465  0.835305
# enginesize       -0.033930  -0.105790  ...   -0.677470  0.874145
# boreratio         0.260064  -0.130051  ...   -0.587012  0.553173
# stroke           -0.160824  -0.008735  ...   -0.043931  0.079443
# compressionratio  0.150276  -0.178515  ...    0.265201  0.067984
# horsepower       -0.015006   0.070873  ...   -0.770544  0.808139
# peakrpm          -0.203789   0.273606  ...   -0.054275 -0.085267
# ...

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(car_df.corr(), cmap='Reds', annot=True)
plt.title('Correlation Matrix of car df');

# %%
car_df_new = car_df.drop(['CarName','fueltype','car_ID','symboling','price','aspiration','carbody','drivewheel','enginelocation','enginetype','fuelsystem'], axis= 'columns')
car_df_new.head()
# Out:
#   doornumber  wheelbase  carlength  ...  peakrpm  citympg  highwaympg
# 0        two       88.6      168.8  ...     5000       21          27
# 1        two       88.6      168.8  ...     5000       21          27
# 2        two       94.5      171.2  ...     5000       19          26
# 3       four       99.8      176.6  ...     5500       24          30
# 4       four       99.4      176.6  ...     5500       18          22
#
# [5 rows x 15 columns]

# %%
target = car_df_new

# %%
target.head()
# Out:
#   doornumber  wheelbase  carlength  ...  peakrpm  citympg  highwaympg
# 0        two       88.6      168.8  ...     5000       21          27
# 1        two       88.6      168.8  ...     5000       21          27
# 2        two       94.5      171.2  ...     5000       19          26
# 3       four       99.8      176.6  ...     5500       24          30
# 4       four       99.4      176.6  ...     5500       18          22
#
# [5 rows x 15 columns]

# %%
pip install word2number
# Out:
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5580 sha256=0da3b06108de48b74a1e37f5bf16f1173cdf4281ca13d05c979c32655791885e
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
# Successfully built word2number
# ...

# %%
from word2number import w2n

# %%
target.doornumber = target['doornumber'].apply(w2n.word_to_num)
target.cylindernumber = target['cylindernumber'].apply(w2n.word_to_num)

# %%
target.head()
# Out:
#    doornumber  wheelbase  carlength  ...  peakrpm  citympg  highwaympg
# 0           2       88.6      168.8  ...     5000       21          27
# 1           2       88.6      168.8  ...     5000       21          27
# 2           2       94.5      171.2  ...     5000       19          26
# 3           4       99.8      176.6  ...     5500       24          30
# 4           4       99.4      176.6  ...     5500       18          22
#
# [5 rows x 15 columns]

# %%
x = target[['doornumber','wheelbase','carlength','carwidth','curbweight','cylindernumber','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']]
y = car_df['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.35)

# %%
model = linear_model.LinearRegression()

# %%
x_train
# Out:
#      doornumber  wheelbase  carlength  ...  peakrpm  citympg  highwaympg
# 187           4       97.3      171.7  ...     4500       37          42
# 119           2       93.7      157.3  ...     5500       24          30
# 17            4      110.0      197.0  ...     5400       15          20
# 83            2       95.9      173.2  ...     5000       19          24
# 9             2       99.5      178.2  ...     5500       16          22
# ..          ...        ...        ...  ...      ...      ...         ...
# 69            2      106.7      187.5  ...     4350       22          25
# 154           4       95.7      169.7  ...     4800       27          32
# 131           2       96.1      176.8  ...     5100       23          31
# 96            4       94.5      165.3  ...     5200       31          37
# 180           4      104.5      187.8  ...     5200       20          24
#
# [133 rows x 14 columns]

# %%
y_train
# Out:
# 187     9495.000
# 119     7957.000
# 17     36880.000
# 83     14869.000
# 9      17859.167
#          ...
# 69     28176.000
# 154     7898.000
# 131     9895.000
# 96      7499.000
# 180    15690.000
# Name: price, Length: 133, dtype: float64

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.8187100353210636

# %%
pre_price = model.predict(x_test)
pre_price
# Out:
# array([ 8584.1345023 , 20800.42972778,  3765.29272218,  6294.96924367,
#         8805.56465054,  9263.71960986,  8798.60364579, 13464.68569669,
#         9788.48933537, 10035.95701382, 16571.67544758, 22496.51922423,
#        13471.40652273,  5208.26838243, 11136.15103894,  5953.96306156,
#        11407.02290674, 31579.20407981,  9451.69390088,  7326.73765424,
#        21237.43388366, 11967.82713919,  7505.26285282,  9717.27402028,
#        18346.18792296, 10340.62112989, 10378.30411778, 10546.5999009 ,
#        12966.71481536, 26660.14637497, 10544.61575902, 26090.89581611,
#        18147.37239212,  7318.90652389,  9671.56354779, 17901.97729956,
#        11131.49011167, 13387.05885213,  7031.284874  , 15443.58356927,
#        10678.89322841,  8246.8185477 , 24641.76811507, 16084.60486302,
#         6337.33843898, 41769.78698809,  6203.18553608, 14419.67636534,
#        15490.53193261,  7689.31110743, 13571.52547811, 10943.562468  ,
# ...
